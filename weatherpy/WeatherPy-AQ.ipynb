# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# sample testing
import json

cities2 = ["Paris", "London", "Oslo","XX", "Beijing", "Nashville", "Stockton", "Seattle", "New York"]

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = "imperial"

cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
temp_max = []
wind_speed = []

counter = 1
setnumb = 1

print("Beginning Data Retrieval")
print("-----------------------------")
    

for city in cities2:
    if counter < 3:
        try:
            query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()
            
            citynamel = weather_json["name"]
            cloudinessl = weather_json["clouds"]["all"]
            countryl = weather_json["sys"]["country"]
            datel = weather_json["dt"]
            humidityl = weather_json["main"]["humidity"]
            latl = weather_json["coord"]["lat"]
            longl = weather_json["coord"]["lon"]
            temp_maxl = weather_json["main"]["temp_max"]
            wind_speedl = weather_json["wind"]["speed"]
            
            cityname.append(citynamel)
            cloudiness.append(cloudinessl)
            country.append(countryl)
            date.append(datel)
            humidity.append(humidityl)
            lat.append(latl)
            long.append(longl)
            temp_max.append(temp_maxl)
            wind_speed.append(wind_speedl)

            print(f'Processing Record {counter} of Set {setnumb} | {city}')
            counter += 1
        except:
            print("City not found. Skipping...")
            counter += 1
            pass
        
    elif counter == 3:
        try:
            query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()
            
            citynamel = weather_json["name"]
            cloudinessl = weather_json["clouds"]["all"]
            countryl = weather_json["sys"]["country"]
            datel = weather_json["dt"]
            humidityl = weather_json["main"]["humidity"]
            latl = weather_json["coord"]["lat"]
            longl = weather_json["coord"]["lon"]
            temp_maxl = weather_json["main"]["temp_max"]
            wind_speedl = weather_json["wind"]["speed"]
            
            cityname.append(citynamel)
            cloudiness.append(cloudinessl)
            country.append(countryl)
            date.append(datel)
            humidity.append(humidityl)
            lat.append(latl)
            long.append(longl)
            temp_max.append(temp_maxl)
            wind_speed.append(wind_speedl)
            
            print(f'Processing Record {counter} of Set {setnumb} | {city}')
            counter = 0
            setnumb += 1
        
        except:
            print("City not founddd. Skipping...")
            counter = 0
            setnumb += 1
            pass
            

            
            
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Paris
# Processing Record 2 of Set 1 | London
# Processing Record 3 of Set 1 | Oslo
# City not found. Skipping...
# Processing Record 1 of Set 2 | Beijing
# Processing Record 2 of Set 2 | Nashville
# Processing Record 3 of Set 2 | Stockton
# Processing Record 0 of Set 3 | Seattle
# Processing Record 1 of Set 3 | New York
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# city list for homework, not testing!

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = "imperial"

cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
temp_max = []
wind_speed = []

counter = 1
setnumb = 1

print("Beginning Data Retrieval")
print("-----------------------------")
    

for city in cities:
    if counter < 50:
        try:
            query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()
            
            citynamel = weather_json["name"]
            cloudinessl = weather_json["clouds"]["all"]
            countryl = weather_json["sys"]["country"]
            datel = weather_json["dt"]
            humidityl = weather_json["main"]["humidity"]
            latl = weather_json["coord"]["lat"]
            longl = weather_json["coord"]["lon"]
            temp_maxl = weather_json["main"]["temp_max"]
            wind_speedl = weather_json["wind"]["speed"]
            
            cityname.append(citynamel)
            cloudiness.append(cloudinessl)
            country.append(countryl)
            date.append(datel)
            humidity.append(humidityl)
            lat.append(latl)
            long.append(longl)
            temp_max.append(temp_maxl)
            wind_speed.append(wind_speedl)

            print(f'Processing Record {counter} of Set {setnumb} | {city}')
            counter += 1
        except:
            print("City not found. Skipping...")
            counter += 1
            pass
        
    elif counter == 50:
        try:
            query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()
            
            citynamel = weather_json["name"]
            cloudinessl = weather_json["clouds"]["all"]
            countryl = weather_json["sys"]["country"]
            datel = weather_json["dt"]
            humidityl = weather_json["main"]["humidity"]
            latl = weather_json["coord"]["lat"]
            longl = weather_json["coord"]["lon"]
            temp_maxl = weather_json["main"]["temp_max"]
            wind_speedl = weather_json["wind"]["speed"]
            
            cityname.append(citynamel)
            cloudiness.append(cloudinessl)
            country.append(countryl)
            date.append(datel)
            humidity.append(humidityl)
            lat.append(latl)
            long.append(longl)
            temp_max.append(temp_maxl)
            wind_speed.append(wind_speedl)
            
            print(f'Processing Record {counter} of Set {setnumb} | {city}')
            counter = 0
            setnumb += 1
        
        except:
            print("City not found. Skipping...")
            counter = 0
            setnumb += 1
            pass
            

            
            
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | norman wells
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | arrecife
# Processing Record 7 of Set 1 | ngunguru
# City not found. Skipping...
# Processing Record 9 of Set 1 | ambilobe
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | vostok
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | lang son
# City not found. Skipping...
# Processing Record 17 of Set 1 | port hardy
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | grand gaube
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | hobyo
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(f'City {len(cityname)}')
print(f'Cloudiness {len(cloudiness)}')
print(f'Country {len(country)}')
print(f'Date {len(date)}')
print(f'Humidity {len(humidity)}')
print(f'Lat {len(lat)}')
print(f'Lng {len(long)}')
print(f'Max Temp {len(temp_max)}')
print(f'Wind Speed {len(wind_speed)}')
# Out:
# City 540
# Cloudiness 540
# Country 540
# Date 540
# Humidity 540
# Lat 540
# Lng 540
# Max Temp 540
# Wind Speed 540

# %%
city_df=pd.DataFrame({
    "City": cityname,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": long,
    "Max Temp": temp_max,
    "Wind Speed": wind_speed    
})

city_df
city_df.index.name = "City_ID"
city_df.to_csv("weather_city_data.csv", index=True, header=True)

# %%
city_df.head()
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0        Norman Wells          75      CA  1586727337        47  65.28
# 1            Saldanha           0      ZA  1586727337        82 -33.01
# 2           Cape Town           0      ZA  1586727067        82 -33.93
# 3              Atuona           4      PF  1586727337        71  -9.80
# 4            Hermanus          10      ZA  1586727337        92 -34.42
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0       -126.83     35.60       10.29
# 1         17.94     57.20        3.36
# 2         18.42     57.00        4.70
# 3       -139.03     82.06        6.04
# 4         19.23     57.00        1.99

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis=city_df["Lat"]
y_axis=city_df["Max Temp"]
today="04/12/2020"
plt.scatter(x_axis, y_axis, marker="o", facecolors="skyblue", edgecolor="black",
            s=y_axis, alpha=0.7)
plt.ylim(0, max(y_axis)+10)
plt.xlim(min(x_axis)-10, max(x_axis)+10)
plt.grid()
plt.title(f'City Latitude vs. Max Temperature ({today})')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("lat_maxtemp.png")
plt.show()

# %% [markdown]
# There's a strong relationship between city latitude and the maximum temperature. A strong positive linear relationship is found between the two factors in the southern hemisphere (less than 0 degrees latitude). On the contrary, a strong negative linear relationship is found bewteen the two factors in the northern hemisphere.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis=city_df["Lat"]
y_axis=city_df["Humidity"]
today="04/12/2020"
plt.scatter(x_axis, y_axis, marker="o", facecolors="skyblue", edgecolor="black",
            s=y_axis, alpha=0.7)
plt.ylim(0, max(y_axis)+50)
plt.xlim(min(x_axis)-10, max(x_axis)+10)
plt.grid()
plt.title(f'City Latitude vs. Humidity ({today})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("lat_humidity.png")
plt.show()

# %% [markdown]
# No observable trend is seen between humidity and latitude. Most data points are clustered between 40% to 100% humidity across both hemispheres.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis=city_df["Lat"]
y_axis=city_df["Cloudiness"]
today="04/12/2020"
plt.scatter(x_axis, y_axis, marker="o", facecolors="skyblue", edgecolor="black",
            s=y_axis, alpha=0.7)
plt.ylim(0, max(y_axis)+5)
plt.xlim(min(x_axis)-10, max(x_axis)+10)
plt.grid()
plt.title(f'City Latitude vs. Cloudiness ({today})')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("lat_cloud.png")
plt.show()

# %% [markdown]
# There's no obvious relationship between cloudiness and latitude.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis=city_df["Lat"]
y_axis=city_df["Wind Speed"]
today="04/12/2020"
plt.scatter(x_axis, y_axis, marker="o", facecolors="skyblue", edgecolor="black",
         alpha=0.9)
plt.ylim(0, max(y_axis)+5)
plt.xlim(min(x_axis)-10, max(x_axis)+10)
plt.grid()
plt.title(f'City Latitude vs. Wind Speed ({today})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("lat_windspeed.png")
plt.show()

# %% [markdown]
# There's no obvious relationship between latitude and wind speed. However, multiple outliers exist.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def linear_regress(x_values, y_values, x_label, y_label, xloc, yloc):
    # Perform a linear regression on temperature vs. latitude
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept


    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    print(line_eq)

    # Create Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")

    # Label plot and annotate the line equation
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.annotate(line_eq,(xloc, yloc),fontsize=15,color="red")
    plt.savefig(f'{x_label}_{y_label}.png')

    # Print r square value
    print(f"The r-squared is: {rvalue**2}")

    # Show plot
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames part 1

city_df["Hemisphere"]=""

for index, row in city_df.iterrows():
    hemi=row["Hemisphere"]
    
    if city_df.iloc[index, 5] >= 0:    
        city_df.loc[index, 'Hemisphere']="Northern"
    else:
        city_df.loc[index, "Hemisphere"]= "Southern"


city_df.head()
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0        Norman Wells          75      CA  1586727337        47  65.28
# 1            Saldanha           0      ZA  1586727337        82 -33.01
# 2           Cape Town           0      ZA  1586727067        82 -33.93
# 3              Atuona           4      PF  1586727337        71  -9.80
# 4            Hermanus          10      ZA  1586727337        92 -34.42
#
#             Lng  Max Temp  Wind Speed Hemisphere
# City_ID
# 0       -126.83     35.60       10.29   Northern
# 1         17.94     57.20        3.36   Southern
# 2         18.42     57.00        4.70   Southern
# 3       -139.03     82.06        6.04   Southern
# 4         19.23     57.00        1.99   Southern

# %%
# Create Northern and Southern Hemisphere DataFrames part 2

north_df=city_df.loc[city_df["Hemisphere"]=="Northern"]
south_df=city_df.loc[city_df["Hemisphere"]=="Southern"]
# Out:
#                     City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0           Norman Wells          75      CA  1586727337        47  65.28
# 5               Arrecife          20      ES  1586727338        63  28.96
# 8        Severo-Kuril'sk          88      RU  1586727338        94  50.68
# 10                Vostok           0      RU  1586727338        72  46.49
# 12                  Hilo          40      US  1586727333        65  19.73
#
#             Lng  Max Temp  Wind Speed Hemisphere
# City_ID
# 0       -126.83     35.60       10.29   Northern
# 5        -13.55     66.20        8.05   Northern
# 8        156.12     30.36        8.52   Northern
# 10       135.88     29.21        2.19   Northern
# 12      -155.09     82.40       10.29   Northern

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regress(north_df["Lat"],north_df["Max Temp"],"Latitude","Max Temp", 10, 18)
# Out:
# y = -0.99x +92.49
# The r-squared is: 0.787884293416847

# %% [markdown]
# A strong negative linear relationship is found between latitude and the max temperature in the northern hemisphere. The R square value is 0.79. Cities with lower latitudes would have higher max temperatures.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regress(south_df["Lat"],south_df["Max Temp"],"Latitude","Max Temp", -30, 45)
# Out:
# y = 0.67x +84.15
# The r-squared is: 0.609691405053278

# %% [markdown]
# A strong positive linear relationship is found bewteen latitude and max temperature in the southern hemisphere. The R sqaure value is 0.61. Cities with higher latitudes would have higher max temperatures.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regress(north_df["Lat"],north_df["Humidity"],"Latitude","Humidity", 40, 13)
# Out:
# y = 0.31x +53.74
# The r-squared is: 0.07642348413854307

# %% [markdown]
# Latitude and humidity are not correlated strongly in the northern hemisphere. Latitude is not a strong predictor for humidity.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regress(south_df["Lat"],south_df["Humidity"],"Latitude","Humidity", -30, 30)
# Out:
# y = 0.21x +76.98
# The r-squared is: 0.022336181370320677

# %% [markdown]
# Latitude and humidity are not correlated strongly in the southern hemisphere. Latitude is not a strong predictor for humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regress(north_df["Lat"],north_df["Cloudiness"],"Latitude","Cloudiness", 40, 15)
# Out:
# y = 0.53x +33.66
# The r-squared is: 0.07457307733908561

# %% [markdown]
# Latitude and cloudiness are not strongly correlated since the R squared value is only 0.07. Latitude is not a strong predictor for cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regress(south_df["Lat"], south_df["Cloudiness"],"Latitude","Cloudiness", -30, 30)
# Out:
# y = 0.66x +64.58
# The r-squared is: 0.056793359257388924

# %% [markdown]
# Latitude and cloudiness are not strongly correlated since the R squared value is only 0.06. Latitude is not a strong predictor for cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regress(north_df["Lat"], north_df["Wind Speed"],"Latitude","Wind Speed", 30, 35)
# Out:
# y = 0.07x +6.67
# The r-squared is: 0.03758016059005641

# %% [markdown]
# Latitude and wind speed are not strongly correlated since the R squared value is only 0.04. Latitude is not a strong predictor for wind speed.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regress(south_df["Lat"], south_df["Wind Speed"],"Latitude","Wind Speed", -30, 30)
# Out:
# y = -0.18x +3.44
# The r-squared is: 0.09848153891542659

# %% [markdown]
# Latitude and wind speed have a weak negative relationship in the southern hemisphere since the R squared value is only 0.10. Latitude is not a strong predictor for wind speed.
